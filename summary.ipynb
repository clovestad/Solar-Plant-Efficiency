# %% [markdown]
# <a href="https://colab.research.google.com/github/clovestad/Solar-Plant-Efficiency/blob/main/summary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Solar plant effiency

# %% [markdown]
# ##stakeholder-
#  small city council considering allocation of funds to start an off grid subdivision , with the question of "how much power can be generated to support the subdivision and its network of buildings and how reliable on a month to month basis will the generation be to gauge the need(if any) for alternative power sources(grid power)
#
#
# ### df info-
#
# Power production predictions to gauge duty cycle of plant components to maintain peak efficiency.

# %% [markdown]
# # Visualizations
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##strengths-
#  monthly generations levels exceed project scope/needs even with outliers(low generating units), due to maintnience or other technical difficulties
#
# ## weaknesses -
#  model cannot predict possible natural disasters(weather)that could impact plant generation or downtime.
#
# ## Final Recommendations -
#  gridseachCV (BestParams)
#
#
#
# ![image.png](data:image/png;base64,...)
